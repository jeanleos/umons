# %% [markdown]
# # Depth Estimation

# %% [markdown]
# In this Jupyter Notebook, we attempt to generate the smaller model with the best accuracy that would fit in the Pynq-Z2. We compare the model generated here with our previous model created in `FINN_depth_estimation`.
#
# For this part of the notebook, the user must download the DIODE dataset (~81GB training and ~2GB evaluation) at this link: https://diode-dataset.org/
#
# Furthermore, the user should create an Anaconda environment containing all the hls4ml dependencies. We used the hls4ml-training repository: https://github.com/fastmachinelearning/hls4ml-tutorial

# %% [markdown]
# ## Imports

# %%
import tensorflow.keras as keras
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']

# %%
import sys
import cv2
from PIL import Image

# %%
import tensorflow.keras.models as models
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
import tensorflow.keras.layers as layers
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPooling2D, UpSampling2D
from qkeras.qlayers import QDense, QActivation
from qkeras import QConv2D, QConv2DBatchnorm
from qkeras.quantizers import quantized_bits, quantized_relu

# %%
import pandas as pd
from qkeras import QDense, QConv2D, QActivation, QBatchNormalization
from qkeras.utils import model_quantize
from PIL import Image

# %%
from qkeras import QConv2D, quantized_bits, quantized_relu

# %%
from IPython.display import clear_output

# %% [markdown]
# ## Training and validation data

# %% [markdown]
# Here, the user should change the variables according to the paths of the DIODE dataset. The maximum sizes allow to train the model on little training data.

# %%
root = os.getcwd()

folder = "val"

path_eval = os.path.join(root, "val")
path_train = "/tools/diode"

max_train_size = 3000000
max_eval_size = 500000000

# %%
size = 32
target_size = (size, size)
modelname = f"depth_{size}.keras"
batch_size = 16

# %% [markdown]
# ## Load data

# %% [markdown]
# Here we load the validation data and read the training directory.

# %%
filelist_train = []
for root, dirs, files in os.walk(path_train):
    for file in files:
        filelist_train.append(os.path.join(root, file))

# %%
filelist_train.sort()
data = {
    "image": [x for x in filelist_train if x.endswith(".png")][:max_train_size],
    "depth": [x for x in filelist_train if x.endswith("_depth.npy")][:max_train_size],
    "mask_": [x for x in filelist_train if x.endswith("_depth_mask.npy")][:max_train_size],
}
df = pd.DataFrame(data)
df = df.sample(frac=1, random_state=42)

# %%
len(data["image"])
# Out:
# 25458

# %%
filelist_eval = []
for root, dirs, files in os.walk(path_eval):
    for file in files:
        filelist_eval.append(os.path.join(root, file))

# %%
filelist_eval.sort()
data_eval = {
    "image": [x for x in filelist_eval if x.endswith(".png")][:max_eval_size],
    "depth": [x for x in filelist_eval if x.endswith("_depth.npy")][:max_eval_size],
    "mask_": [x for x in filelist_eval if x.endswith("_depth_mask.npy")][:max_eval_size],
}

# %%
len(data_eval["image"])
# Out:
# 771

# %%
X = []
for x_path in data_eval["image"]:
    img = tf.keras.preprocessing.image.load_img(x_path, target_size=(size, size, 3))
    img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
    X.append(img)
X = np.stack(X, axis=0)

# %%
Y = []
i = 0
for d_path in data_eval["depth"]:
    
    depth = np.load(d_path).astype(np.float32)
    
    depth_mask = np.load(data_eval['mask_'][i]).astype(np.float32).squeeze()
    depth[depth_mask == 0] = np.mean(depth)
    depth = (depth - 0.3) / (30.0 - 0.3)
    depth = np.clip(depth, 0.0, 1.0)
    
    depth = tf.image.resize(depth, (size, size))
    depth = tf.keras.preprocessing.image.img_to_array(depth)
    
    Y.append(depth)
    
    i += 1
Y = np.stack(Y, axis=0)

# %% [markdown]
# ## Create a model

# %% [markdown]
# Creating a model that respects the U-Net architecture and has a correct accuracy has to be done empirically according to the resource usage after Vitis HLS synthesis. In this example, we use two 4 filters convolutions for the encoder, a 8 filters convolution for the bottleneck and two 4 filters convolutions for the decoder. Eventually we use an element-wise convolution for the output.

# %%
"""
64
70.8984962406015% LUT Usage
93.21428571428572% BRAM_18K Usage
2.727272727272727% DSP Usage
24.48872180451128% FF Usage
0.0% URAM Usage

32

56.47932330827068% LUT Usage
42.857142857142854% BRAM_18K Usage
2.727272727272727% DSP Usage
21.87218045112782% FF Usage
0.0% URAM Usage

32 8-16-32
177.76127819548873% LUT Usage
162.85714285714286% BRAM_18K Usage
2.727272727272727% DSP Usage
70.10526315789474% FF Usage
0.0% URAM Usage

32 4-8-16-8-4
90.72744360902256% LUT Usage
83.21428571428572% BRAM_18K Usage
2.727272727272727% DSP Usage
40.088345864661655% FF Usage
0.0% URAM Usage
"""
def unet_model(input_shape=(size, size, 3)):
    
    inputs = layers.Input(shape=input_shape)

    c0 = layers.Conv2D(4, 3, padding='same', activation='relu')(inputs)
    p0 = layers.MaxPooling2D((2, 2))(c0)
    
    c1 = layers.Conv2D(8, 3, padding='same', activation='relu')(p0)
    p1 = layers.MaxPooling2D((2, 2))(c1)
    
    c2 = layers.Conv2D(16, 3, padding='same', activation='relu')(p1)
    
    c3 = layers.Conv2D(8, 3, padding='same', activation='relu')(c2)
    c3 = layers.UpSampling2D(size=(2, 2))(c3)
    u3 = layers.concatenate([c1, c3])
    
    c4 = layers.Conv2D(4, 3, padding='same', activation='relu')(u3)
    c4 = layers.UpSampling2D(size=(2, 2))(c4)
    u4 = layers.concatenate([c0, c4])
    
    c5 = layers.Conv2D(1, 3, padding='same', activation='sigmoid')(u4)

    model = models.Model(inputs=inputs, outputs=c5)
    return model

# %% [markdown]
# ## Model compilation

# %% [markdown]
# To compile the model, we can use various loss functions such as MSE, MAE or SSIM. We define SSIM if the user want to further explore it.

# %% [markdown]
# SSIM stands for Structural Similarity Index and evaluates the similarity between two images.

# %%
def ssim_loss(y_true, y_pred):
    return 1.0 - tf.reduce_mean(
        tf.image.ssim(y_true, y_pred, max_val=tf.reduce_max(y_true))
    )

def combined_ssim_loss(y_true, y_pred, alpha=1.0, beta=1.0, gamma=0.5):

    mse = tf.reduce_mean(tf.square(y_true - y_pred))

    dy_t, dx_t = tf.image.image_gradients(y_true)
    dy_p, dx_p = tf.image.image_gradients(y_pred)
    grad_loss = tf.reduce_mean(tf.abs(dy_t - dy_p) + tf.abs(dx_t - dx_p))

    ssim_l = ssim_loss(y_true, y_pred)
    return alpha * mse + beta * grad_loss + gamma * ssim_l

def ssim_mse_loss(y_true, y_pred):
    return combined_ssim_loss(y_true, y_pred, alpha=1.0, beta=1.0, gamma=0.5)

# %% [markdown]
# We compile our model using the Adam algorithm and use the MSE loss function. To evaluate the evaluations, we use MAE.

# %%
model = unet_model(input_shape=(size, size, 3))

model.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss="mse",
    metrics=["mae"],
)

model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_11 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 4)            112       ['input_11[0][0]']
#
#  max_pooling2d_18 (MaxPooli  (None, 16, 16, 4)            0         ['conv2d_42[0][0]']
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 8)            296       ['max_pooling2d_18[0][0]']
#
#  max_pooling2d_19 (MaxPooli  (None, 8, 8, 8)              0         ['conv2d_43[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 16)             1168      ['max_pooling2d_19[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 8)              1160      ['conv2d_44[0][0]']
#
#  up_sampling2d_17 (UpSampli  (None, 16, 16, 8)            0         ['conv2d_45[0][0]']
#  ng2D)
#
# ...

# %% [markdown]
# ## Dynamic learning data loading

# %% [markdown]
# To avoid loading all the learning data in the RAM, we use a dynamic data generator.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, dataframe, target_size=(256, 256), batch_size=32, shuffle=True):
        self.data = dataframe
        self.target_size = target_size
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.data))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.data) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_data = self.data.iloc[batch_indices]
        X, Y = self.__data_generation(batch_data)
        return X, Y

    def __data_generation(self, batch_data):
        X = []
        Y = []
        for i, row in batch_data.iterrows():
            img = tf.keras.preprocessing.image.load_img(
                row["image"], target_size=(self.target_size[0], self.target_size[1])
            )
            img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            X.append(img)

            depth = np.load(row["depth"]).astype(np.float32)

            depth_mask = np.load(row['mask_']).astype(np.float32).squeeze()
            depth[depth_mask == 0] = np.mean(depth)

            depth = (depth - 0.3) / (30.0 - 0.3)
            depth = np.clip(depth, 0.0, 1.0)
            depth = tf.image.resize(depth, (self.target_size[0], self.target_size[1]))
            depth = tf.keras.preprocessing.image.img_to_array(depth)
            Y.append(depth)

        X = np.stack(X, axis=0)
        Y = np.stack(Y, axis=0)
        return X, Y

# %%
df = pd.DataFrame(data)
df = df.sample(frac=1, random_state=42)
training_generator = DataGenerator(df, target_size=target_size, batch_size=batch_size)

# %% [markdown]
# ## Dynamic plotting

# %% [markdown]
# To prevent over-fitting, we can observe the learning and the evaluation graphs and stop the learning process when needed.

# %%
class LivePlotCallback(tf.keras.callbacks.Callback):
    def __init__(self, X_val, Y_val):
        super().__init__()
        self.X_val = X_val
        self.Y_val = Y_val
        self.train_losses = []
        self.train_accuracies = []
        self.val_losses = []
        self.val_accuracies = []

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.train_losses.append(logs.get('loss'))
        self.train_accuracies.append(logs.get('accuracy'))

        val_loss, val_acc = self.model.evaluate(self.X_val, self.Y_val, verbose=0)
        self.val_losses.append(val_loss)
        self.val_accuracies.append(val_acc)

        clear_output(wait=True)
        epochs = range(1, len(self.train_losses) + 1)

        plt.figure(figsize=(14, 5))

        # loss plot
        plt.subplot(1, 2, 1)
        plt.plot(epochs, self.train_losses, label='Training Loss')
        plt.plot(epochs, self.val_losses, label='Evaluation Loss')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)

        # accuracy plot
        plt.subplot(1, 2, 2)
        plt.plot(epochs, self.train_accuracies, label='Training Error')
        plt.plot(epochs, self.val_accuracies, label='Evaluation Error')
        plt.title('Error over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Error')
        plt.legend()
        plt.grid(True)

        plt.tight_layout()
        plt.show()

# %%
live_plot_cb = LivePlotCallback(X, Y)

history = model.fit(
    training_generator,
    epochs=10000,
    batch_size=batch_size,
    callbacks=[
        live_plot_cb,
        tf.keras.callbacks.ModelCheckpoint(modelname)
    ]
)
# Out:
# 1592/1592 [==============================] - 1379s 866ms/step - loss: 0.0424 - mae: 0.1428
# Epoch 23/10000
#    9/1592 [..............................] - ETA: 21:12 - loss: 0.0409 - mae: 0.1375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[170], line 3
#       1 live_plot_cb = LivePlotCallback(X, Y)
# ----> 3 history = model.fit(
#       4     training_generator,
#       5     epochs=10000,
#       6     batch_size=batch_size,
#       7     callbacks=[
#       8         live_plot_cb,
#       9         tf.keras.callbacks.ModelCheckpoint(modelname)
#      10     ]
#      11 )
#
# File ~/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
# ...

# %% [markdown]
# ## Validation using images

# %% [markdown]
# In this part of the notebook, we evaluate the performance of the trained model on unseen images.

# %%
from keras.saving import load_model
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
model = load_model(modelname, custom_objects=co, safe_mode=False)
model.summary()

# %%
for weight in model.weights:
    print(f"Name: {weight.name}")
    print(f"Shape: {weight.shape}")
    print(weight.numpy())

# %% [markdown]
# ### DIODE image
#
# Here we use an image provided in the evaluation part of the DIODE dataset.

# %%
img = tf.keras.preprocessing.image.load_img(
    "./val/outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_040.png",
    target_size=(size, size)
)
img = tf.keras.preprocessing.image.img_to_array(img) / 255.0  

img_batch = tf.expand_dims(img, axis=0)
res_batch = model.predict(img_batch)

im = res_batch[0, :, :, 0]

fig, axes = plt.subplots(1, 4, figsize=(6, 3))

axes[2].imshow(im, cmap='jet')
axes[2].axis('off')

axes[1].imshow(img, cmap='jet')
axes[1].axis('off')

axes[0].imshow(tf.keras.preprocessing.image.load_img(
    "./val/outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_040.png",
), cmap='jet')
axes[0].axis('off')

axes[3].imshow(np.clip(np.load("./val/outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_000_depth.npy"), 0, 30), cmap='jet')
axes[3].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %% [markdown]
# ### Outdoor image
#
# Here we use an image of the landscape seen outside of one of the UMons SEMi's windows.

# %%
img = tf.keras.preprocessing.image.load_img(
    "IMG_1087.jpg",
    target_size=(size, size)
)
img = tf.keras.preprocessing.image.img_to_array(img) / 255.0  

img_batch = tf.expand_dims(img, axis=0)
res_batch = model.predict(img_batch)

im = res_batch[0, :, :, 0]

fig, axes = plt.subplots(1, 3, figsize=(6, 3))

axes[2].imshow(np.rot90(im, k=3), cmap='jet')
axes[2].axis('off')

axes[1].imshow(np.rot90(img, k=3), cmap='jet')
axes[1].axis('off')

axes[0].imshow(np.rot90(tf.keras.preprocessing.image.load_img(
    "IMG_1087.jpg",
), k=3), cmap='jet')
axes[0].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %% [markdown]
# ## hls4ml

# %% [markdown]
# In this part, we use hls4ml to synthetise and implement our model for the Pynq-Z2.
#
# **Important:** hls4ml currently only supports 2020.1 tools so it is import to `source` the correct Vivado installation.

# %%
import hls4ml
import plotting

config = hls4ml.utils.config_from_keras_model(model, granularity='model')
config['Model']['Precision']['default'] = 'ap_fixed<16,6>'
config['Model']['ReuseFactor'] = 4_000_000_000_000
config['Model']['Strategy'] = 'Resource'

print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")

hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config,
    output_dir='pynqz2m2/hls4ml_prj_pynq',
    backend='VivadoAccelerator',
    board='pynq-z2',
    io_type='io_stream'
)
hls_model.compile()
# Out:
# Interpreting Model
# Topology:
# Layer name: input_11, layer type: InputLayer, input shapes: [[None, 32, 32, 3]], output shape: [None, 32, 32, 3]
# Layer name: conv2d_42, layer type: Conv2D, input shapes: [[None, 32, 32, 3]], output shape: [None, 32, 32, 4]
# Layer name: max_pooling2d_18, layer type: MaxPooling2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 16, 16, 4]
# Layer name: conv2d_43, layer type: Conv2D, input shapes: [[None, 16, 16, 4]], output shape: [None, 16, 16, 8]
# Layer name: max_pooling2d_19, layer type: MaxPooling2D, input shapes: [[None, 16, 16, 8]], output shape: [None, 8, 8, 8]
# Layer name: conv2d_44, layer type: Conv2D, input shapes: [[None, 8, 8, 8]], output shape: [None, 8, 8, 16]
# Layer name: conv2d_45, layer type: Conv2D, input shapes: [[None, 8, 8, 16]], output shape: [None, 8, 8, 8]
# Layer name: up_sampling2d_17, layer type: UpSampling2D, input shapes: [[None, 8, 8, 8]], output shape: [None, 16, 16, 8]
# ...

# %% [markdown]
# ## Comparison between real model and quantized model (CPU)
#
# hls4ml allows us to compare the output model.

# %%
img_hls = tf.keras.preprocessing.image.load_img(
    "./val/outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_040.png",
    target_size=(size, size)
)
img_hls = tf.keras.preprocessing.image.img_to_array(img_hls) / 255.0  

img_batch_hls = tf.expand_dims(img_hls, axis=0)
hls_im = hls_model.predict(img_batch_hls.numpy()).reshape((size, size, 1))

fig, axes = plt.subplots(1, 2, figsize=(6, 3))

axes[1].imshow(hls_im, cmap='jet')
axes[1].axis('off')

axes[0].imshow(im, cmap='jet')
axes[0].axis('off')

plt.tight_layout()
plt.show()

# %%
plotting.print_dict(hls4ml.backends.get_backend('Vitis').create_initial_config())
# Out:
# Part:                xcvu13p-flga2577-2-e
# ClockPeriod:         5
# ClockUncertainty:    27%
# IOType:              io_parallel
# HLSConfig
# WriterConfig
#   Namespace:         None
#   WriteWeightsTxt:   True
#   WriteTar:          False

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# ## Synthetise and Implement
#
# We use `build` to run the synthesis and the implementation. After this we can retrieve the `.bit` and `.hwh` files.

# %%
buildres = hls_model.build(csim=False, synth=True, export=True, bitfile=True)
buildres
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'jeanleo2' on host 'administrateur-ThinkStation-P2-Tower' (Linux_x86_64 version 6.11.0-26-generic) on Fri Jun 27 09:41:31 CEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04.2 LTS
# INFO: [HLS 200-10] In directory '/home/jeanleo2/hls4ml2/pynqz2m2/hls4ml_prj_pynq'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Opening project '/home/jeanleo2/hls4ml2/pynqz2m2/hls4ml_prj_pynq/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject_axi.cpp' to the project
# ...

# %% [markdown]
# If the implementation fails, we can set `synth=True` and all the rest to `False` and use the following log to have an idea of resource utilisation.

# %%
print(f"""{int(buildres['CSynthesisReport']['LUT'])/int(buildres['CSynthesisReport']['AvailableLUT'])*100}% LUT Usage
{int(buildres['CSynthesisReport']['BRAM_18K'])/int(buildres['CSynthesisReport']['AvailableBRAM_18K'])*100}% BRAM_18K Usage
{int(buildres['CSynthesisReport']['DSP'])/int(buildres['CSynthesisReport']['AvailableDSP'])*100}% DSP Usage
{int(buildres['CSynthesisReport']['FF'])/int(buildres['CSynthesisReport']['AvailableFF'])*100}% FF Usage
{int(buildres['CSynthesisReport']['URAM'])/1 if int(buildres['CSynthesisReport']['AvailableURAM']) == 0 else int(buildres['CSynthesisReport']['AvailableURAM'])*100}% URAM Usage""")
# Out:
# 90.72744360902256% LUT Usage
# 83.92857142857143% BRAM_18K Usage
# 2.727272727272727% DSP Usage
# 40.10244360902256% FF Usage
# 0.0% URAM Usage

# %% [markdown]
# We can also use the `design_1_wrapper_utilization_placed.rpt` file to further analise the resource utilisation.

# %%
# !sed -n '30,45p' pynqz2m2/hls4ml_prj_pynq/myproject_vivado_accelerator/project_1.runs/impl_1/design_1_wrapper_utilization_placed.rpt
# Out:
# +----------------------------+-------+-------+-----------+-------+
# |          Site Type         |  Used | Fixed | Available | Util% |
# +----------------------------+-------+-------+-----------+-------+
# | Slice LUTs                 | 27152 |     0 |     53200 | 51.04 |
# |   LUT as Logic             | 23924 |     0 |     53200 | 44.97 |
# |   LUT as Memory            |  3228 |     0 |     17400 | 18.55 |
# |     LUT as Distributed RAM |    22 |     0 |           |       |
# |     LUT as Shift Register  |  3206 |     0 |           |       |
# | Slice Registers            | 35188 |     0 |    106400 | 33.07 |
# |   Register as Flip Flop    | 35188 |     0 |    106400 | 33.07 |
# |   Register as Latch        |     0 |     0 |    106400 |  0.00 |
# | F7 Muxes                   |  1892 |     0 |     26600 |  7.11 |
# | F8 Muxes                   |   450 |     0 |     13300 |  3.38 |
# +----------------------------+-------+-------+-----------+-------+

# %% [markdown]
# Copy the generated files into `pynqz2m2/hls4ml_prk_pynq/package`.
# We can use `scp -r package xilinx@addr_pynq:folder` to copy the files over the Pynq-Z2 board.

# %%
# !mkdir -p pynqz2m2/hls4ml_prj_pynq/package
# !cp pynqz2m2/hls4ml_prj_pynq/myproject_vivado_accelerator/project_1.runs/impl_1/design_1_wrapper.bit pynqz2m2/hls4ml_prj_pynq/package/hls4ml_nn.bit
# !cp pynqz2m2/hls4ml_prj_pynq/myproject_vivado_accelerator/project_1.srcs/sources_1/bd/design_1/hw_handoff/design_1.hwh pynqz2m2/hls4ml_prj_pynq/package/hls4ml_nn.hwh
# !cp pynqz2m2/hls4ml_prj_pynq/axi_stream_driver.py pynqz2m2/hls4ml_prj_pynq/package/
# !cp part7b_deployment.ipynb pynqz2m2/hls4ml_prj_pynq/package

# !tar -czvf pynqz2m2/hls4ml_prj_pynq/package.tar.gz -C pynqz2m2/hls4ml_prj_pynq/package/ .
# Out:
# ./
# ./hls4ml_nn.bit
# ./hls4ml_nn.hwh
# ./part7b_deployment.ipynb
# ./axi_stream_driver.py

# %% [markdown]
# # Archive
#
# Here we leave some unsuccessful attempts (not fitting, bad accuracy, etc.)

# %% [raw]
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(inputs)
#     c1 = layers.BatchNormalization()(c1)
#     c1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(c1)
#     c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(p1)
#     c2 = layers.BatchNormalization()(c2)
#     c2 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(c2)
#     c2 = layers.BatchNormalization()(c2)
#     p2 = layers.MaxPooling2D((2, 2))(c2)
#
#     c3 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(p2)
#     c3 = layers.BatchNormalization()(c3)
#     c3 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(c3)
#     c3 = layers.BatchNormalization()(c3)
#     p3 = layers.MaxPooling2D((2, 2))(c3)
#
#     # bottleneck
#     c4 = layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu')(p3)
#     c4 = layers.BatchNormalization()(c4)
#     c4 = layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu')(c4)
#     c4 = layers.BatchNormalization()(c4)
#
#     # decoder
#     u5 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c4)
#     u5 = layers.concatenate([u5, c3])
#     c5 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(u5)
#     c5 = layers.BatchNormalization()(c5)
#     c5 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(c5)
#     c5 = layers.BatchNormalization()(c5)
#
#     u6 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
#     u6 = layers.concatenate([u6, c2])
#     c6 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(u6)
#     c6 = layers.BatchNormalization()(c6)
#     c6 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(c6)
#     c6 = layers.BatchNormalization()(c6)
#
#     u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = layers.concatenate([u7, c1])
#     c7 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(u7)
#     c7 = layers.BatchNormalization()(c7)
#     c7 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(c7)
#     c7 = layers.BatchNormalization()(c7)
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c7)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model

# %% [raw]
# def unet_model(input_shape=(32, 32, 1)):
#
#     model = Sequential()
#     model.add(layers.Input(shape=input_shape))
#     model.add(layers.Conv2D(1, (3, 3), padding='same'))
#     model.add(Activation(activation="sigmoid"))
#
#     return model

# %% [raw]
# """def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#
#     # encoder
#     c1 = layers.Conv2D(16, kernel_size=3, padding='same', activation='relu')(inputs)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     # bottleneck
#     c4 = layers.Conv2D(16, kernel_size=3, padding='same', activation='relu')(p1)
#     c4 = layers.UpSampling2D(size=(2,2))(c4)
#     #c4 = layers.concatenate([c4, c1])
#
#     outputs = layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid')(c4)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model"""
#
# def unet_model(input_shape=(256, 256, 1)):
#     inputs = layers.Input(shape=input_shape)
#
#     c1 = layers.Conv2D(16, 3, padding='same', activation='relu')(inputs)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = layers.Conv2D(16, 3, padding='same', activation='relu')(p1)
#
#     u2 = layers.UpSampling2D((2, 2))(c2)
#     u2 = layers.Concatenate()([u2, c1])
#
#     outputs = layers.Conv2D(1, 3, padding='same', activation='sigmoid')(u2)
#
#     return models.Model(inputs=inputs, outputs=outputs)

# %% [raw]
# # tel4
#
# def unet_model(input_shape=(size, size, 1), base_filters=20):
#     inputs = layers.Input(shape=input_shape)
#
#     x = QConv2D(base_filters, (3, 3), padding='same', activation='relu')(inputs)
#     x = layers.BatchNormalization()(x)
#
#     # dilated convolution stack to capture multi‐scale context
#     for dilation in [2, 4, 8]:
#         x = QConv2D(base_filters, (3, 3),
#                     padding='same',
#                     dilation_rate=dilation,
#                     activation='relu')(x)
#         x = layers.BatchNormalization()(x)
#
#     # final 1×1 projection to single‐channel depth map
#     outputs = QConv2D(1, (1, 1), padding='same', activation='sigmoid')(x)
#
#     return models.Model(inputs, outputs)

# %% [raw]
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(inputs)
#     c1 = layers.BatchNormalization()(c1)
#     c1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(c1)
#     c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(p1)
#     c2 = layers.BatchNormalization()(c2)
#     c2 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(c2)
#     c2 = layers.BatchNormalization()(c2)
#     p2 = layers.MaxPooling2D((2, 2))(c2)
#
#     c3 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(p2)
#     c3 = layers.BatchNormalization()(c3)
#     c3 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(c3)
#     c3 = layers.BatchNormalization()(c3)
#     p3 = layers.MaxPooling2D((2, 2))(c3)
#
#     # bottleneck
#     c4 = layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu')(p3)
#     c4 = layers.BatchNormalization()(c4)
#     c4 = layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu')(c4)
#     c4 = layers.BatchNormalization()(c4)
#
#     # decoder
#     #u5 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c4)
#     u5 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(c4)
#     u5 = layers.UpSampling2D(size=(2,2))(u5)
#     u5 = layers.concatenate([u5, c3])
#     c5 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(u5)
#     c5 = layers.BatchNormalization()(c5)
#     c5 = layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu')(c5)
#     c5 = layers.BatchNormalization()(c5)
#
#     #u6 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
#     u6 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(u5)
#     u6 = layers.UpSampling2D(size=(2,2))(u6)
#     u6 = layers.concatenate([u6, c2])
#     c6 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(u6)
#     c6 = layers.BatchNormalization()(c6)
#     c6 = layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu')(c6)
#     c6 = layers.BatchNormalization()(c6)
#
#     #u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(c6)
#     u7 = layers.UpSampling2D(size=(2,2))(u7)
#     u7 = layers.concatenate([u7, c1])
#     c7 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(u7)
#     c7 = layers.BatchNormalization()(c7)
#     c7 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(c7)
#     c7 = layers.BatchNormalization()(c7)
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c7)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model

# %% [raw]
# pre = 0
#
# def ds_conv2d(x, filters, kernel_size=(3,3), strides=(1,1), padding='same'):
#
#     global pre
#
#     dw = layers.DepthwiseConv2D(
#             kernel_size=kernel_size,
#             strides=strides,
#             padding=padding,
#             activation='relu',
#             name=f'ds_conv_el0_{pre}')(x)
#     dw = layers.BatchNormalization()(dw)
#
#     pw = layers.Conv2D(
#              filters,
#              kernel_size=(1,1),
#              strides=(1,1),
#              padding='valid',
#              activation='relu',
#             name=f'ds_conv_el1_{pre}')(dw)
#
#     pre += 1
#
#     return pw

# %% [raw]
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c1 = ds_conv2d(inputs, 32)
#     #c1 = layers.BatchNormalization()(c1)
#     c1 = ds_conv2d(c1, 32)
#     #c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     # bottleneck
#     c4 = ds_conv2d(p1, 64)
#     #c4 = layers.BatchNormalization()(c4)
#     c4 = ds_conv2d(c4, 64)
#     #c4 = layers.BatchNormalization()(c4)
#
#     #u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = ds_conv2d(c4, 32)
#     u7 = layers.UpSampling2D(size=(2,2))(u7)
#     u7 = layers.concatenate([u7, c1])
#     c7 = ds_conv2d(u7, 32)
#     #c7 = layers.BatchNormalization()(c7)
#     c7 = ds_conv2d(c7, 32)
#     #c7 = layers.BatchNormalization()(c7)
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c7)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model

# %% [raw]
# def depthwise_conv_block(x, filters, name_prefix):
#     # depthwise convolution
#     x = layers.DepthwiseConv2D(
#         kernel_size=3,
#         padding='same',
#         activation='relu',
#         name=f'{name_prefix}_depthwise'
#     )(x)
#
#     # pointwise convolution
#     x = layers.Conv2D(
#         filters=filters,
#         kernel_size=1,
#         padding='same',
#         activation='relu',
#         name=f'{name_prefix}_pointwise'
#     )(x)
#
#     return x
#
#
# def unet_model(input_shape=(size, size, 3)):
#     inputs = layers.Input(shape=input_shape)
#
#     conv1 = layers.Conv2D(4, 3, padding='same', activation='relu', name='initial_conv')(inputs) #64x64x4
#     pool1 = layers.MaxPooling2D(2, name='pool1')(conv1) #32x32x4
#
#     # encoder l1
#     conv2 = depthwise_conv_block(pool1, 8, 'enc1') #32x32x8
#     pool2 = layers.MaxPooling2D(2, name='pool2')(conv2) #16x16x8
#
#     # bottleneck
#     bottleneck = depthwise_conv_block(pool2, 16, 'bottleneck') #16x16x16
#
#     # decoder l1
#     up1 = layers.UpSampling2D(2, name='up1')(bottleneck) #32x32x16
#     up1 = layers.Conv2D(8, 1, padding='same', activation='relu', name='up1_reduce')(up1)
#     merge1 = layers.concatenate([conv2, up1], name='merge1') #32x32x16
#     dec1 = depthwise_conv_block(merge1, 8, 'dec1') #32x32x8
#
#     # decoder l2
#     up2 = layers.UpSampling2D(2, name='up2')(dec1) #64x64x8
#     up2 = layers.Conv2D(4, 1, padding='same', activation='relu', name='up2_reduce')(up2)
#     merge2 = layers.concatenate([conv1, up2], name='merge2') #64x64x8
#     dec2 = depthwise_conv_block(merge2, 4, 'dec2') #64x64x4
#
#     outputs = layers.Conv2D(1, 1, activation='sigmoid', name='depth_output')(dec2)
#
#     model = models.Model(inputs=inputs, outputs=outputs, name='unet')
#
#     model.compile(
#         optimizer='adam',
#         loss='mae',
#         metrics=['mse']
#     )
#
#     return model
#
# def unet_model(input_shape=(size, size, 3)):
#
#     inputs = layers.Input(shape=input_shape)
#
#     conv1_1 = depthwise_conv_block(inputs, 16, 'conv1')#layers.Conv2D(16, 3, padding='same', activation='relu')(inputs)
#     conv1_2 = depthwise_conv_block(conv1_1, 16, 'conv2')#layers.Conv2D(16, 3, padding='same', activation='relu')(conv1_1)
#     pool1 = layers.MaxPooling2D(2)(conv1_2)
#
#     conv2_1 = depthwise_conv_block(pool1, 32, 'conv3')#layers.Conv2D(32, 3, padding='same', activation='relu')(pool1)
#     conv2_2 = depthwise_conv_block(conv2_1, 32, 'conv4')#layers.Conv2D(32, 3, padding='same', activation='relu')(conv2_1)
#     pool2 = layers.MaxPooling2D(2)(conv2_2)
#
#     conv3_1 = depthwise_conv_block(pool2, 64, 'conv5')#layers.Conv2D(64, 3, padding='same', activation='relu')(pool2)
#     conv3_2 = depthwise_conv_block(conv3_1, 64, 'conv6')#layers.Conv2D(64, 3, padding='same', activation='relu')(conv3_1)
#     pool3 = layers.MaxPooling2D(2)(conv3_2)
#
#     conv4_1 = depthwise_conv_block(pool3, 128, 'conv7')#layers.Conv2D(128, 3, padding='same', activation='relu')(pool3)
#     conv4_2 = depthwise_conv_block(conv4_1, 128, 'conv8')#layers.Conv2D(128, 3, padding='same', activation='relu')(conv4_1)
#
#     up5 = layers.UpSampling2D(2)(conv4_2)
#     up5 = depthwise_conv_block(up5, 64, 'conv9')#layers.Conv2D(64, 3, padding='same', activation='relu')(up5)
#     merge5 = layers.concatenate([conv3_2, up5])
#     conv5_1 = depthwise_conv_block(merge5, 64, 'conv10')#layers.Conv2D(64, 3, padding='same', activation='relu')(merge5)
#     conv5_2 = depthwise_conv_block(conv5_1, 64, 'conv11')#layers.Conv2D(64, 3, padding='same', activation='relu')(conv5_1)
#
#     up6 = layers.UpSampling2D(2)(conv5_2)
#     up6 = depthwise_conv_block(up6, 32, 'conv12')#layers.Conv2D(32, 3, padding='same', activation='relu')(up6)
#     merge6 = layers.concatenate([conv2_2, up6])
#     conv6_1 = depthwise_conv_block(merge6, 32, 'conv13')#layers.Conv2D(32, 3, padding='same', activation='relu')(merge6)
#     conv6_2 = depthwise_conv_block(conv6_1, 32, 'conv14')#layers.Conv2D(32, 3, padding='same', activation='relu')(conv6_1)
#
#     up7 = layers.UpSampling2D(2)(conv6_2)
#     up7 = depthwise_conv_block(up7, 16, 'conv15')#layers.Conv2D(16, 3, padding='same', activation='relu')(up7)
#     merge7 = layers.concatenate([conv1_2, up7])
#     conv7_1 = depthwise_conv_block(merge7, 16, 'conv16')#layers.Conv2D(16, 3, padding='same', activation='relu')(merge7)
#     conv7_2 = depthwise_conv_block(conv7_1, 16, 'conv17')#layers.Conv2D(16, 3, padding='same', activation='relu')(conv7_1)
#
#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv7_2)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#
#     model.compile(
#         optimizer='adam',
#         loss='mae',
#         metrics=['mse']
#     )
#
#     return model
#
# def unet_model(input_shape=(size, size, 3)):
#
#     inputs = layers.Input(shape=input_shape)
#
#     conv1_1 = layers.Conv2D(16, 3, padding='same', activation='relu')(inputs)
#     conv1_2 = layers.Conv2D(16, 3, padding='same', activation='relu')(conv1_1)
#     pool1 = layers.MaxPooling2D(2)(conv1_2)
#
#     conv4_1 = layers.Conv2D(32, 3, padding='same', activation='relu')(pool1)
#     conv4_2 = layers.Conv2D(32, 3, padding='same', activation='relu')(conv4_1)
#
#     up7 = layers.UpSampling2D(2)(conv4_2)
#     up7 = layers.Conv2D(16, 3, padding='same', activation='relu')(up7)
#     merge7 = layers.concatenate([conv1_2, up7])
#     conv7_1 = layers.Conv2D(16, 3, padding='same', activation='relu')(merge7)
#     conv7_2 = layers.Conv2D(16, 3, padding='same', activation='relu')(conv7_1)
#
#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv7_2)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#
#     model.compile(
#         optimizer='adam',
#         loss='mae',
#         metrics=['mse']
#     )
#
#     return model
#
# def unet_model(input_shape=(size, size, 3)):
#
#     inputs = layers.Input(shape=input_shape)
#
#     conv1_1 = layers.Conv2D(16, 3, padding='same', activation='relu')(inputs)
#     conv1_2 = layers.Conv2D(16, 3, padding='same', activation='relu')(conv1_1)
#     pool1 = layers.MaxPooling2D(2)(conv1_2)
#
#     conv2_1 = layers.Conv2D(32, 3, padding='same', activation='relu')(pool1)
#     conv2_2 = layers.Conv2D(32, 3, padding='same', activation='relu')(conv2_1)
#     pool2 = layers.MaxPooling2D(2)(conv2_2)
#
#     #conv3_1 = layers.Conv2D(64, 3, padding='same', activation='relu')(pool2)
#     #conv3_2 = layers.Conv2D(64, 3, padding='same', activation='relu')(conv3_1)
#     #pool3 = layers.MaxPooling2D(2)(conv3_2)
#
#     conv4_1 = layers.Conv2D(32, 3, padding='same', activation='relu')(pool2)
#     conv4_2 = layers.Conv2D(32, 3, padding='same', activation='relu')(conv4_1)
#
#     #up5 = layers.UpSampling2D(2)(conv4_2)
#     #up5 = layers.Conv2D(64, 3, padding='same', activation='relu')(up5)
#     #merge5 = layers.concatenate([conv3_2, up5])
#     #conv5_1 = layers.Conv2D(64, 3, padding='same', activation='relu')(merge5)
#     #conv5_2 = layers.Conv2D(64, 3, padding='same', activation='relu')(conv5_1)
#
#     up6 = layers.UpSampling2D(2)(conv4_2)
#     up6 = layers.Conv2D(32, 3, padding='same', activation='relu')(up6)
#     #merge6 = layers.concatenate([conv2_2, up6])
#     conv6_1 = layers.Conv2D(32, 3, padding='same', activation='relu')(up6)
#     conv6_2 = layers.Conv2D(32, 3, padding='same', activation='relu')(conv6_1)
#
#     up7 = layers.UpSampling2D(2)(conv6_2)
#     up7 = layers.Conv2D(16, 3, padding='same', activation='relu')(up7)
#     #merge7 = layers.concatenate([conv1_2, up7])
#     conv7_1 = layers.Conv2D(16, 3, padding='same', activation='relu')(up7)
#     conv7_2 = layers.Conv2D(16, 3, padding='same', activation='relu')(conv7_1)
#
#     outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv7_2)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#
#     model.compile(
#         optimizer='adam',
#         loss='mae',
#         metrics=['mse']
#     )
#
#     return model

# %% [raw]
# padding="valid"

# %% [raw]
# def single_conv_down(inputs, out_channels, padding="valid", name=None):
#     x = Conv2D(out_channels, 3, activation="relu", padding=padding)(inputs)
#     x = MaxPooling2D(2, padding=padding, name=name)(x)
#     return x
#
# def single_conv_down_parts(inputs, out_channels, parts, padding="valid", name=None):
#     #x_parts = []
#     #for part in range(parts):
#     #    x = Conv2D(out_channels//parts, 3, activation="relu", padding=padding)(inputs)
#     #    x = MaxPooling2D(2, padding=padding)(x)
#     #    x_parts.append(x)
#
#     x_1 = Conv2D(out_channels//2, 3, activation="relu", padding=padding)(inputs)
#     x_1 = MaxPooling2D(2, padding=padding)(x_1)
#
#     x_2 = Conv2D(out_channels//2, 3, activation="relu", padding=padding)(inputs)
#     x_2 = MaxPooling2D(2, padding=padding)(x_2)
#
#     #x_3 = Conv2D(out_channels//4, 3, activation="relu", padding=padding)(inputs)
#     #x_3 = MaxPooling2D(2, padding=padding)(x_3)
#
#     #x_4 = Conv2D(out_channels//4, 3, activation="relu", padding=padding)(inputs)
#     #x_4 = MaxPooling2D(2, padding=padding)(x_4)
#
#     x = layers.Concatenate(name=name)([x_1, x_2])
#     #x_6 = layers.Concatenate()([x_3, x_4])
#     #x = layers.Concatenate(name=name)([x_5, x_6])
#
#     return x
#
# def single_conv_up(inputs, out_channels, padding="valid", name=None):
#     x = Conv2D(out_channels, 3, activation="relu", padding=padding)(inputs)
#     x = UpSampling2D(2, interpolation="nearest", name=name)(x)
#     return x
#
# def single_conv_up_parts(inputs, out_channels, parts, padding="valid", name=None):
#     x_parts = []
#     for part in range(parts):
#         x = Conv2D(out_channels//parts, 3, activation="relu", padding=padding)(inputs)
#         x = UpSampling2D(2)(x)
#         x_parts.append(x)
#     x = layers.Concatenate(name=name)(x_parts)
#     return x
#
# def double_conv_down(inputs, out_channels):
#     x = Conv2D(out_channels, 3, activation="relu", padding="same")(inputs)
#     x = Conv2D(out_channels, 3, activation="relu", padding="same")(x)
#     x = MaxPooling2D(2, padding="same")(x)
#     return x
#
# def double_conv_up(inputs, out_channels):
#     x = Conv2D(out_channels, 3, activation="relu", padding="same")(inputs)
#     x = Conv2D(out_channels, 3, activation="relu", padding="same")(x)
#     x = UpSampling2D(2)(x)
#     return x
#
#
# def single_qconv_down(inputs, out_channels, nbits, nbitsi):
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(inputs)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = MaxPooling2D(2, padding="same")(x)
#     return x
#
# def single_qconv_up(inputs, out_channels, nbits, nbitsi):
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(inputs)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = UpSampling2D(2)(x)
#     return x
#
# def double_qconv_down(inputs, out_channels, nbits, nbitsi):
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(inputs)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(x)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = MaxPooling2D(2, padding="same")(x)
#     return x
#
# def double_qconv_up(inputs, out_channels, nbits, nbitsi):
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(inputs)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = QConv2D(
#         out_channels,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same"
#     )(x)
#     x = QActivation(f'quantized_relu({nbits})')(x)
#     x = UpSampling2D(2)(x)
#     return x
#
# def build_depth_autoencoder(input_shape=(32, 32, 3)):
#     inputs = layers.Input(shape=input_shape, name="input_image")
#
#     # ------- Encoder -------
#     x = single_conv_down(inputs, 32, padding=padding)
#     x = single_conv_down(x, 64, padding=padding)
#     encoded = single_conv_down(x, 256, padding=padding, name="encoded")
#
#     # ------- Decoder -------
#     x = single_conv_up(encoded, 256, padding=padding)
#     x = single_conv_up(x, 64, padding=padding)
#     x = single_conv_up(x, 32, padding=padding)
#
#     outputs = Conv2D(1, 3, activation="sigmoid", padding=padding,
#                             name="reconstructed_depth")(x)
#
#     return models.Model(inputs, outputs, name="depth_autoencoder")
#
#
# def build_depth_autoencoder_parts(input_shape=(32, 32, 3)):
#     inputs = layers.Input(shape=input_shape, name="input_image")
#
#     # ------- Encoder -------
#     x = single_conv_down_parts(inputs, 32, 1, padding=padding)
#     x = single_conv_down_parts(x, 64, 8, padding=padding)
#     encoded = single_conv_down_parts(x, 256, 32, padding=padding, name="encoded")
#
#     # ------- Decoder -------
#     x = single_conv_up(encoded, 256, padding=padding)
#     x = single_conv_up(x, 64, padding=padding)
#     x = single_conv_up(x, 32, padding=padding)
#
#     outputs = Conv2D(1, 3, activation="sigmoid", padding=padding,
#                             name="reconstructed_depth")(x)
#
#     return models.Model(inputs, outputs, name="depth_autoencoder")
#
#
# def build_depth_autoencoder_sc(input_shape=(32, 32, 3)):
#     inputs = layers.Input(shape=input_shape, name="input_image")
#
#     # ------- Encoder -------
#     x1 = single_conv_down(inputs, 64)
#     x2 = single_conv_down(x1, 64)
#     x3 = single_conv_down(x2, 64)
#
#     # ------- Decoder -------
#     x4 = single_conv_up(x3, 64)
#     x4 = layers.Concatenate()([x4, x2])
#     x5 = single_conv_up(x4, 64)
#     x5 = layers.Concatenate()([x5, x1])
#     x6 = single_conv_up(x5, 64)
#
#     outputs = Conv2D(1, 3, activation="sigmoid", padding="same",
#                             name="reconstructed_depth")(x6)
#
#     return models.Model(inputs, outputs, name="depth_autoencoder")
#
# def build_depth_q_autoencoder(input_shape=(32, 32, 3)):
#     inputs = layers.Input(shape=input_shape, name="input_depth")
#
#     # ------- Encoder -------
#     x = single_qconv_down(inputs, 16, 16, 6)
#     x = single_qconv_down(x, 16, 16, 6)
#     encoded = single_qconv_down(x, 16, 16, 6)
#
#     # ------- Decoder -------
#     x = single_qconv_up(encoded, 16, 16, 6)
#     x = single_qconv_up(x, 16, 16, 6)
#     x = single_qconv_up(x, 16, 16, 6)
#
#     outputs = layers.Conv2D(1, 3, activation="sigmoid", padding="same",
#                             name="reconstructed_depth")(x)
#
#     return models.Model(inputs, outputs, name="depth_autoencoder")
#
# model = build_depth_autoencoder(input_shape=(size, size, 3))
# model.summary()

# %% [raw]
# # ─────────────────────────────────────────────────────────────
# # 2. Slice out the ENCODER
# #    (input ➜ latent feature map)
# # ─────────────────────────────────────────────────────────────
# encoder = models.Model(
#     inputs=model.input,
#     outputs=model.get_layer("encoded").output,
#     name="encoder"
# )
# encoder.summary()
#
#
#
# # ─────────────────────────────────────────────────────────────
# # 3. Splice together the DECODER
# #    (latent feature map ➜ reconstructed depth)
# # ─────────────────────────────────────────────────────────────
# # 3-a) Create a fresh tensor that will play the role of "latent input"
# latent_shape = model.get_layer("encoded").output.shape[1:]  # (4,4,128)
# decoder_inp = layers.Input(shape=latent_shape, name="decoder_input")
#
# # 3-b) Re-use *exactly* the layers that follow the latent layer
# latent_index = model.layers.index(model.get_layer("encoded"))
# x = decoder_inp
# for layer in model.layers[latent_index + 1:]:
#     x = layer(x)                   # same layer objects → shared weights
#
# decoder = models.Model(decoder_inp, x, name="decoder")
# decoder.summary()

# %% [raw]
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c1 = ds_conv2d(inputs, 32)
#     c1 = layers.BatchNormalization()(c1)
#     c1 = ds_conv2d(c1, 32)
#     c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     # bottleneck
#     c4 = ds_conv2d(p1, 64)
#     c4 = layers.BatchNormalization()(c4)
#     c4 = ds_conv2d(c4, 64)
#     c4 = layers.BatchNormalization()(c4)
#
#     #u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = ds_conv2d(c4, 32)
#     u7 = layers.UpSampling2D(size=(2,2))(u7)
#     u7 = layers.concatenate([u7, c1])
#     c7 = ds_conv2d(u7, 32)
#     c7 = layers.BatchNormalization()(c7)
#     c7 = ds_conv2d(c7, 32)
#     c7 = layers.BatchNormalization()(c7)
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c7)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model
#
#
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     c0 = ds_conv2d(inputs, 16)
#     c0 = layers.BatchNormalization()(c0)
#     c0 = ds_conv2d(c0, 16)
#     c0 = layers.BatchNormalization()(c0)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     # encoder
#     c1 = ds_conv2d(p0, 32)
#     c1 = layers.BatchNormalization()(c1)
#     c1 = ds_conv2d(c1, 32)
#     c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     # bottleneck
#     c4 = layers.concatenate([ds_conv2d(p1, 8), ds_conv2d(p1, 8), ds_conv2d(p1, 8), ds_conv2d(p1, 8)])
#     c4 = layers.BatchNormalization()(c4)
#     c5 = layers.concatenate([ds_conv2d(c4, 8), ds_conv2d(c4, 8), ds_conv2d(c4, 8), ds_conv2d(c4, 8)])#ds_conv2d(c4, 64)
#     c5 = layers.BatchNormalization()(c5)
#
#     #u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = ds_conv2d(c5, 32)
#     u7 = layers.UpSampling2D(size=(2,2))(u7)
#     u7 = layers.concatenate([u7, c1])
#     c7 = ds_conv2d(u7, 32)
#     c7 = layers.BatchNormalization()(c7)
#     c7 = ds_conv2d(c7, 32)
#     c7 = layers.BatchNormalization()(c7)
#
#     u8 = ds_conv2d(c7, 16)
#     u8 = layers.UpSampling2D(size=(2,2))(u8)
#     u8 = layers.concatenate([u8, c0])
#     c8 = ds_conv2d(u8, 16)
#     c8 = layers.BatchNormalization()(c8)
#     c8 = ds_conv2d(c8, 16)
#     c8 = layers.BatchNormalization()(c8)
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c8)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model

# %% [raw]
# def unet_model(input_shape=(target_size[0], target_size[1], 1)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     """c0 = ds_conv2d(inputs, 16)
#     c0 = layers.BatchNormalization()(c0)
#     c0 = ds_conv2d(c0, 16)
#     c0 = layers.BatchNormalization()(c0)
#     p0 = layers.MaxPooling2D((2, 2))(c0)"""
#
#     # encoder
#     c1 = ds_conv2d(inputs, 32)
#     c1 = layers.BatchNormalization()(c1)
#     c1 = ds_conv2d(c1, 32)
#     c1 = layers.BatchNormalization()(c1)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     # bottleneck
#     c4 = ds_conv2d(p1, 64)
#     c4 = layers.BatchNormalization()(c4)
#     c4 = ds_conv2d(c4, 64)
#     c4 = layers.BatchNormalization()(c4)
#
#     #u7 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
#     u7 = ds_conv2d(c4, 32)
#     u7 = layers.UpSampling2D(size=(2,2))(u7)
#     u7 = layers.concatenate([u7, c1])
#     c7 = ds_conv2d(u7, 32)
#     c7 = layers.BatchNormalization()(c7)
#     c7 = ds_conv2d(c7, 32)
#     c7 = layers.BatchNormalization()(c7)
#
#     """u8 = ds_conv2d(c7, 16)
#     u8 = layers.UpSampling2D(size=(2,2))(u8)
#     u8 = layers.concatenate([u8, c0])
#     c8 = ds_conv2d(u8, 16)
#     c8 = layers.BatchNormalization()(c8)
#     c8 = ds_conv2d(c8, 16)
#     c8 = layers.BatchNormalization()(c8)"""
#
#
#     outputs = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid')(c7)
#
#     model = models.Model(inputs=inputs, outputs=outputs)
#     return model
#
# # 92% bram
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = layers.Conv2D(4, 3, padding='same', activation='relu')(inputs)
#     c1 = layers.Conv2D(16, 3, padding='same', activation='relu')(c0)
#     c2 = layers.Conv2D(32, 3, padding='same', activation='relu')(c1)
#     c3 = layers.Conv2D(16, 3, padding='same', activation='relu')(c2)
#     c4 = layers.Conv2D(4, 3, padding='same', activation='relu')(c3)
#     c5 = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(c4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model
#
# # 130% bram
# # 64x64
# """
# 9.020695262641139% LUT Usage
# 40.07936507936508% BRAM_18K Usage
# 0.06648936170212766% DSP Usage
# 2.458195262641139% FF Usage
# 0.0% URAM Usage
# """
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = layers.Conv2D(4, 3, padding='same', activation='relu')(inputs)
#
#     c1 = layers.Conv2D(16, 3, padding='same', activation='relu')(c0)
#
#     c2 = layers.Conv2D(32, 3, padding='same', activation='relu')(c1)
#
#     c3 = layers.Conv2D(16, 3, padding='same', activation='relu')(c2)
#     c3 = layers.concatenate([c1, c3])
#
#     c4 = layers.Conv2D(4, 3, padding='same', activation='relu')(c3)
#     c4 = layers.concatenate([c0, c4])
#
#     c5 = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(c4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model
#
# """
# 64x64
# 6.791390525282277% LUT Usage
# 19.59325396825397% BRAM_18K Usage
# 0.06648936170212766% DSP Usage
# 2.765210787923417% FF Usage
# 0.0% URAM Usage
# """
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = layers.Conv2D(8, 3, padding='same', activation='relu')(inputs)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     c1 = layers.Conv2D(16, 3, padding='same', activation='relu')(p0)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = layers.Conv2D(32, 3, padding='same', activation='relu')(p1)
#
#     c3 = layers.Conv2D(16, 3, padding='same', activation='relu')(c2)
#     c3 = layers.UpSampling2D(size=(2, 2))(c3)
#     u3 = layers.concatenate([c1, c3])
#
#     c4 = layers.Conv2D(8, 3, padding='same', activation='relu')(u3)
#     c4 = layers.UpSampling2D(size=(2, 2))(c4)
#     u4 = layers.concatenate([c0, c4])
#
#     c5 = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(u4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model
#
# """
# 128 128
# 13.925579896907218% LUT Usage
# 59.27579365079365% BRAM_18K Usage
# 0.06648936170212766% DSP Usage
# 3.943414027982327% FF Usage
# 96000% URAM Usage
# """
# """
# 64x64
# 6.791390525282277% LUT Usage
# 19.59325396825397% BRAM_18K Usage
# 0.06648936170212766% DSP Usage
# 2.765210787923417% FF Usage
# 0.0% URAM Usage
# """
# """
# pynq-z2
#
# 167.48308270676694% LUT Usage
# 292.1428571428571% BRAM_18K Usage
# 2.727272727272727% DSP Usage
# 68.30263157894737% FF Usage
# 1% URAM Usage
# """
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#
#     #new2
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = layers.Conv2D(8, 3, padding='same', activation='relu')(inputs)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     c1 = layers.Conv2D(16, 3, padding='same', activation='relu')(p0)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = layers.Conv2D(32, 3, padding='same', activation='relu')(p1)
#
#     c3 = layers.Conv2D(16, 3, padding='same', activation='relu')(c2)
#     c3 = layers.UpSampling2D(size=(2, 2))(c3)
#     u3 = layers.concatenate([c1, c3])
#
#     c4 = layers.Conv2D(8, 3, padding='same', activation='relu')(u3)
#     c4 = layers.UpSampling2D(size=(2, 2))(c4)
#     u4 = layers.concatenate([c0, c4])
#
#     c5 = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(u4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model
#
# """
# pynq-z2
# 158.11278195488723% LUT Usage
# 198.92857142857144% BRAM_18K Usage
# 0.0% DSP Usage
# 54.65413533834587% FF Usage
# 0.0% URAM Usage
# 8,4
#
# 158.11278195488723% LUT Usage
# 199.64285714285714% BRAM_18K Usage
# 0.0% DSP Usage
# 54.66823308270676% FF Usage
# 0.0% URAM Usage
# 4,2
#
# 155.04887218045113% LUT Usage
# 185.35714285714286% BRAM_18K Usage
# 0.0% DSP Usage
# 51.690789473684205% FF Usage
# 0.0% URAM Usage
# 32 -> 20
#
# 198.4624060150376% LUT Usage
# 182.14285714285714% BRAM_18K Usage
# 0.0% DSP Usage
# 51.16917293233083% FF Usage
# 0.0% URAM Usage
# conv end 1
#
# 177.08082706766916% LUT Usage
# 159.64285714285717% BRAM_18K Usage
# 0.0% DSP Usage
# 42.72744360902256% FF Usage
# 0.0% URAM Usage
# no medium
# """
# nbits, nbitsi = 4, 2
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = QConv2D(
#         8,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(inputs)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     c1 = QConv2D(
#         16,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p0)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = QConv2D(
#         20,#32,4,2v2
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p1)
#
#     c3 = QConv2D(
#         16,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p1)
#     c3 = layers.UpSampling2D(size=(2, 2))(c3)
#     u3 = layers.concatenate([c1, c3])
#
#     c4 = QConv2D(
#         8,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(u3)
#     c4 = layers.UpSampling2D(size=(2, 2))(c4)
#     u4 = layers.concatenate([c0, c4])
#
#     c5 = QConv2D(
#         1,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="sigmoid"
#     )(u4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model
#
# """
# 104.44736842105262% LUT Usage
# 102.85714285714285% BRAM_18K Usage
# 0.0% DSP Usage
# 30.543233082706767% FF Usage
# 0.0% URAM Usage
# z2 4 8 16
#
# 100.66353383458646% LUT Usage
# 83.21428571428572% BRAM_18K Usage
# 0.0% DSP Usage
# 25.704887218045116% FF Usage
# 0.0% URAM Usage
# 4 8 14
# """
# nbits, nbitsi = 4, 2
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(inputs)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     c1 = QConv2D(
#         8,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p0)
#     p1 = layers.MaxPooling2D((2, 2))(c1)
#
#     c2 = QConv2D(
#         14,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p1)
#
#     c3 = QConv2D(
#         8,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(c2)
#     c3 = layers.UpSampling2D(size=(2, 2))(c3)
#     u3 = layers.concatenate([c1, c3])
#
#     c4 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(u3)
#     c4 = layers.UpSampling2D(size=(2, 2))(c4)
#     u4 = layers.concatenate([c0, c4])
#
#     c5 = QConv2D(
#         1,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="sigmoid"
#     )(u4)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model

# %% [raw]
# """
# 104.44736842105262% LUT Usage
# 102.85714285714285% BRAM_18K Usage
# 0.0% DSP Usage
# 30.543233082706767% FF Usage
# 0.0% URAM Usage
# z2 4 8 16
#
# 100.66353383458646% LUT Usage
# 83.21428571428572% BRAM_18K Usage
# 0.0% DSP Usage
# 25.704887218045116% FF Usage
# 0.0% URAM Usage
# 4 8 14
#
# 5-10-5
# 68.11654135338347% LUT Usage
# 67.5% BRAM_18K Usage
# 0.0% DSP Usage
# 17.86936090225564% FF Usage
# 0.0% URAM Usage
#
# 4-4-8-4-4
# 63.75375939849624% LUT Usage
# 67.14285714285714% BRAM_18K Usage
# 0.0% DSP Usage
# 17.768796992481203% FF Usage
# 0.0% URAM Usage
# """
# nbits, nbitsi = 8, 4
# def unet_model(input_shape=(target_size[0], target_size[1], 3)):
#     inputs = layers.Input(shape=input_shape)
#
#     # encoder
#     c0 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(inputs)
#     p00 = layers.MaxPooling2D((2, 2))(c0)
#     c00 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p00)
#     p0 = layers.MaxPooling2D((2, 2))(c0)
#
#     c2 = QConv2D(
#         8,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(p0)
#
#     c3 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(c2)
#     c3 = layers.UpSampling2D(size=(2, 2))(c3)
#     u3 = layers.concatenate([c0, c3])
#     u3 = QConv2D(
#         4,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="relu"
#     )(u3)
#
#     c5 = QConv2D(
#         1,
#         kernel_size=(3, 3),
#         strides=(1, 1),
#         kernel_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         bias_quantizer=f"quantized_bits({nbits},{nbitsi},alpha=1)",
#         kernel_initializer='lecun_uniform',
#         kernel_regularizer=l1(0.0001),
#         use_bias=True,
#         padding="same",
#         activation="sigmoid"
#     )(u3)
#
#     model = models.Model(inputs=inputs, outputs=c5)
#     return model

# %% [raw]
# import hls4ml
# import plotting
#
# config = hls4ml.utils.config_from_keras_model(model, granularity='model')
# config['Model']['Precision']['default'] = 'ap_fixed<8,4>'
# config['Model']['ReuseFactor'] = 4096
# config['Model']['Strategy'] = 'Resource'
#
# cfg = hls4ml.converters.create_config(board='alveo-u280', clock_period=2, part='xcu280-fsvh2892-2L-e', backend='VivadoAccelerator')
# cfg['HLSConfig'] = config
#
# cfg['AcceleratorConfig'] = {}
# cfg['AcceleratorConfig']['Driver']    = 'python'
# cfg['AcceleratorConfig']['Board']     = 'alveo-u280'
# cfg['AcceleratorConfig']['Platform']  = 'xilinx_u280_gen3x16_xdma_1_202211_1'
# cfg['AcceleratorConfig']['Precision'] = {
#     'Input': 'ap_fixed<8,4>',
#     'Output': 'ap_fixed<8,4>'
# }
#
# cfg['IOType'] = 'io_stream'
# cfg['KerasModel'] = model
# cfg['OutputDir'] = os.getcwd() + '/alveo_out/alveo'
#
# print("-----------------------------------")
# plotting.print_dict(cfg)
# print("-----------------------------------")
#
# hls_model = hls4ml.converters.keras_to_hls(cfg)
# hls_model.compile()

# %% [raw]
# import hls4ml
# import plotting
#
# config = hls4ml.utils.config_from_keras_model(model, granularity='model', backend='VivadoAccelerator')
# config['Model']['Precision']['default'] = 'ap_fixed<8,4>' #16,5
# config['Model']['ReuseFactor'] = 4096 #4_000_000_000_000
# config['Model']['Strategy'] = 'Resource'
# #config['Model']['Strategy'] = 'Unrolled'
# #config['ClockPeriod'] = 20
#
# cfg = hls4ml.converters.create_config(board='alveo-u280', clock_period=2, part='xcu280-fsvh2892-2L-e', backend='VivadoAccelerator')
# cfg['HLSConfig'] = config
#
# cfg['AcceleratorConfig'] = {}
# cfg['AcceleratorConfig']['Driver']    = 'python'
# cfg['AcceleratorConfig']['Board']     = 'alveo-u280'
# cfg['AcceleratorConfig']['Platform']  = 'xilinx_u280_gen3x16_xdma_1_202211_1'
# cfg['AcceleratorConfig']['Precision'] = {
#     'Input': 'ap_fixed<8,4>',
#     'Output': 'ap_fixed<8,4>'
# }
#
# cfg['IOType'] = 'io_stream'
# cfg['KerasModel'] = model
# cfg['OutputDir'] = os.getcwd() + '/alveo_out/alveo'
#
# print("-----------------------------------")
# plotting.print_dict(cfg)
# print("-----------------------------------")
#
# #pynq-z2
# """hls_model = hls4ml.converters.convert_from_keras_model(
#     model,
#     hls_config=cfg,
#     output_dir='outfolder/pynq',
#     backend='VivadoAccelerator',
#     board='pynq-z2',
#     #part='xck26-sfvc784-2LV-c',
#     part='xc7z020clg400-1',
#     io_type='io_stream',
#     clock_period=20,
# )"""
# hls_model = hls4ml.converters.keras_to_hls(cfg)
# hls_model.compile()

# %% [raw]
# import hls4ml
# import plotting
#
# config = hls4ml.utils.config_from_keras_model(model, backend='Vitis', granularity='model')
# config['Model']['ReuseFactor'] = 4096
# config['Model']['Strategy'] = 'Resource'
# config['ClockPeriod'] = 5
#
# # Full Vitis backend config
# cfg = hls4ml.converters.create_config(
#     backend='Vitis',
#     board='alveo-u280',
#     clock_period=5,
#     part='xcu280-fsvh2892-2L-e'
# )
#
# cfg['HLSConfig'] = config
# cfg['AcceleratorConfig'] = {
#     'Driver': 'python',
#     'Board': 'alveo-u280',
#     'Platform': 'xilinx_u280_gen3x16_xdma_1_202211_1'
# }
# cfg['IOType'] = 'io_stream'
# cfg['KerasModel'] = model
# cfg['OutputDir'] = os.path.join(os.getcwd(), 'outfolder_vitis10', 'vitis_build')
#
# # Build and compile
# hls_model = hls4ml.converters.keras_to_hls(cfg)
# hls_model.compile()
# hls_model.build(csim=False, synth=True, export=True)

# %% [raw]
# 1000:
#
# 4.734290623465881% LUT Usage
# 7.0436507936507935% BRAM_18K Usage
# 0.7646276595744681% DSP Usage.
#
# 4000:
#
# 4.337337383406971% LUT Usage
# 5.33234126984127% BRAM_18K Usage
# 0.31028368794326244% DSP Usage.

# %% [raw]
# bigger model + 32
# 8.072533136966127% LUT Usage
# 9.499007936507937% BRAM_18K Usage
# 0.5540780141843972% DSP Usage.
#
# dsconv 64
# 14.648533382425136% LUT Usage
# 13.740079365079366% BRAM_18K Usage
# 17.29831560283688% DSP Usage.
#
# all conv 64
#
# 37.09292157584683% LUT Usage
# 28.670634920634917% BRAM_18K Usage
# 103.62367021276594% DSP Usage.
#
# all conv 64 + 4B unroll
#
# 36.98553325969563% LUT Usage
# 28.670634920634917% BRAM_18K Usage
# 102.24955673758865% DSP Usage.
#
# + clock 10
#
# 36.64633959253805% LUT Usage
# 28.670634920634917% BRAM_18K Usage
# 102.24955673758865% DSP Usage.
#
# <15,6>
#
# 37.77054185076093% LUT Usage
# 28.670634920634917% BRAM_18K Usage
# 83.2668439716312% DSP Usage
# 9.353368924889544% FF Usage
# 0.0% URAM Usage

# %% [raw]
# 128 128 no normalisation
#
# 36.9028442562592% LUT Usage
# 25.744047619047617% BRAM_18K Usage
# 81.91489361702128% DSP Usage
# 9.242950724104075% FF Usage
# 0.0% URAM Usage
#
# big model (128 max + depth)
#
# 147.15942562592048% LUT Usage
# 48.80952380952381% BRAM_18K Usage
# 319.90248226950354% DSP Usage
# 24.05597999509082% FF Usage
# 0.0% URAM Usage

# %% [raw]
# 16/32 no concatenate
#
# 5.915562101129111% LUT Usage
# 6.4732142857142865% BRAM_18K Usage
# 0.2327127659574468% DSP Usage
# 4.8870888561610215% FF Usage
# 0.0% URAM Usage
#
# 16/32 concatenate
#
# 6.453424153166422% LUT Usage
# 7.490079365079365% BRAM_18K Usage
# 0.22163120567375888% DSP Usage
# 5.326844010800196% FF Usage
# 0.0% URAM Usage
#
# 16/32/32 no concatenate (unroll)
#
# 177.28054430535101% LUT Usage
# 12.003968253968255% BRAM_18K Usage
# 0.2770390070921986% DSP Usage
# 36.93801392979872% FF Usage
# 0.0% URAM Usage
#
# 32/64//
#
# 35.64456001472754% LUT Usage
# 25.744047619047617% BRAM_18K Usage
# 83.42198581560284% DSP Usage
# 8.580403166421208% FF Usage
# 0.0% URAM Usage
#
# 32/64 norm
#
# 36.74444648993618% LUT Usage
# 28.670634920634917% BRAM_18K Usage
# 82.50221631205675% DSP Usage
# 8.906480117820324% FF Usage
# 0.0% URAM Usage
#
# 16/32/64 norm
#
# 45.1245704467354% LUT Usage
# 39.0625% BRAM_18K Usage
# 98.47074468085107% DSP Usage
# 11.889727540500736% FF Usage
# 0.0% URAM Usage
#
# 16/32/64 norm valid
#
# 45.11160714285714% LUT Usage
# 39.0625% BRAM_18K Usage
# 98.93617021276596% DSP Usage
# 11.889727540500736% FF Usage
# 0.0% URAM Usage
#
# em half
#
# 54.913092169857634% LUT Usage
# 38.913690476190474% BRAM_18K Usage
# 0.0% DSP Usage
# 4.183465267550319% FF Usage
# 0.0% URAM Usage
